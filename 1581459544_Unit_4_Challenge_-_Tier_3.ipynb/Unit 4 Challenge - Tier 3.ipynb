# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np


# Load the pyplot collection of functions from matplotlib, as plt 
from matplotlib import pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
# Transpose the DataFrame
properties_transposed = properties.transpose()
properties_transposed.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001          91448.98487          82202.77314
# Barking & Dagenham  E09000002           50460.2266          51085.77983
# Barnet              E09000003          93284.51832          93190.16963
# Bexley              E09000004          64958.09036          64787.92069
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London              79120.70256          77101.20804
# Barking & Dagenham          51268.96956          53133.50526
# Barnet                      92247.52435          90762.87492
# Bexley                      64367.49344          64277.66881
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
# Reset the index of the transposed DataFrame
properties_transposed_reset = properties_transposed.reset_index()

# Drop the original index column (the first row becomes the header)
properties_transposed_reset.columns = properties_transposed_reset.iloc[0]
properties_transposed_reset = properties_transposed_reset.drop(0).reset_index(drop=True)
properties_transposed_reset.head(100)
# Out:
# 0             Unnamed: 0        NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 0         City of London  E09000001         91448.98487         82202.77314
# 1     Barking & Dagenham  E09000002          50460.2266         51085.77983
# 2                 Barnet  E09000003         93284.51832         93190.16963
# 3                 Bexley  E09000004         64958.09036         64787.92069
# 4                  Brent  E09000005         71306.56698         72022.26197
# 5                Bromley  E09000006         81671.47692         81657.55944
# 6                 Camden  E09000007         120932.8881         119508.8622
# 7                Croydon  E09000008         69158.16225         68951.09542
# 8                 Ealing  E09000009         79885.89069         80897.06551
# 9                Enfield  E09000010         72514.69096         73155.19746
# 10             Greenwich  E09000011         62300.10169         60993.26863
# ...

# %%
# Rename DF to properties_new
properties_new = properties_transposed_reset
properties_new.head()
# Out:
# 0          Unnamed: 0        NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 0      City of London  E09000001         91448.98487         82202.77314
# 1  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 2              Barnet  E09000003         93284.51832         93190.16963
# 3              Bexley  E09000004         64958.09036         64787.92069
# 4               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 0         79120.70256         77101.20804         84409.14932
# 1         51268.96956         53133.50526         53042.24852
# 2         92247.52435         90762.87492         90258.00033
# 3         64367.49344         64277.66881         63997.13588
# 4         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 0         94900.51244         110128.0423         112329.4376  ...
# ...

# %%
# Make indices starting from 1
properties_new.reset_index(drop=True)   
properties_new.index = properties_new.index+1
properties_new.head()
# Out:
# 0          Unnamed: 0        NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
print(type(properties_new))
# Rename columns
properties_new = properties_new.rename(columns={properties_new.columns[0]: 'Borough', properties_new.columns[1]: 'Geocode'})
properties_new.head(50)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 0                Borough    Geocode 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1         City of London  E09000001         91448.98487         82202.77314
# 2     Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3                 Barnet  E09000003         93284.51832         93190.16963
# 4                 Bexley  E09000004         64958.09036         64787.92069
# 5                  Brent  E09000005         71306.56698         72022.26197
# 6                Bromley  E09000006         81671.47692         81657.55944
# 7                 Camden  E09000007         120932.8881         119508.8622
# 8                Croydon  E09000008         69158.16225         68951.09542
# 9                 Ealing  E09000009         79885.89069         80897.06551
# 10               Enfield  E09000010         72514.69096         73155.19746
# 11             Greenwich  E09000011         62300.10169         60993.26863
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
# Melt df
properties_melted = properties_new.melt(id_vars=['Borough','Geocode'])
properties_melted.index = properties_melted.index+1
properties_melted.head()
# Out:
#               Borough    Geocode                    0        value
# 1      City of London  E09000001  1995-01-01 00:00:00  91448.98487
# 2  Barking & Dagenham  E09000002  1995-01-01 00:00:00   50460.2266
# 3              Barnet  E09000003  1995-01-01 00:00:00  93284.51832
# 4              Bexley  E09000004  1995-01-01 00:00:00  64958.09036
# 5               Brent  E09000005  1995-01-01 00:00:00  71306.56698

# %%
#Rename columns [2,3]
properties_melted = properties_melted.rename(columns={properties_melted.columns[2]: 'Date', properties_melted.columns[3]: 'Avg_Price'})

# %%
properties_melted.head(50)
# Out:
#                  Borough    Geocode       Date     Avg_Price  Year
# 1         City of London  E09000001 1995-01-01   91448.98487  1995
# 2     Barking & Dagenham  E09000002 1995-01-01   50460.22660  1995
# 3                 Barnet  E09000003 1995-01-01   93284.51832  1995
# 4                 Bexley  E09000004 1995-01-01   64958.09036  1995
# 5                  Brent  E09000005 1995-01-01   71306.56698  1995
# 6                Bromley  E09000006 1995-01-01   81671.47692  1995
# 7                 Camden  E09000007 1995-01-01  120932.88810  1995
# 8                Croydon  E09000008 1995-01-01   69158.16225  1995
# 9                 Ealing  E09000009 1995-01-01   79885.89069  1995
# 10               Enfield  E09000010 1995-01-01   72514.69096  1995
# 11             Greenwich  E09000011 1995-01-01   62300.10169  1995
# 12               Hackney  E09000012 1995-01-01   61296.52637  1995
# 13  Hammersmith & Fulham  E09000013 1995-01-01  124902.86020  1995
# ...

# %%
# List of boroughs to keep
london_boroughs = ["Barking & Dagenham", "Barnet", "Bexley", "Brent", "Bromley", "Camden", "Croydon", "Ealing", "Enfield", "Greenwich", "Hackney", "Hammersmith & Fulham", "Haringey", "Harrow", "Havering", "Hillingdon", "Hounslow", "Islington", "Kensington & Chelsea", "Kingston upon Thames", "Lambeth", "Lewisham", "Merton", "Newham", "Redbridge", "Richmond upon Thames", "Southwark", "Sutton", "Tower Hamlets", "Waltham Forest", "Wandsworth", "Westminster"]

# Filter the DataFrame for the specified boroughs
properties_filtered = properties_melted[properties_melted['Borough'].isin(london_boroughs)]
properties_filtered.head(50)
# Out:
#                  Borough    Geocode       Date     Avg_Price  Year
# 2     Barking & Dagenham  E09000002 1995-01-01   50460.22660  1995
# 3                 Barnet  E09000003 1995-01-01   93284.51832  1995
# 4                 Bexley  E09000004 1995-01-01   64958.09036  1995
# 5                  Brent  E09000005 1995-01-01   71306.56698  1995
# 6                Bromley  E09000006 1995-01-01   81671.47692  1995
# 7                 Camden  E09000007 1995-01-01  120932.88810  1995
# 8                Croydon  E09000008 1995-01-01   69158.16225  1995
# 9                 Ealing  E09000009 1995-01-01   79885.89069  1995
# 10               Enfield  E09000010 1995-01-01   72514.69096  1995
# 11             Greenwich  E09000011 1995-01-01   62300.10169  1995
# 12               Hackney  E09000012 1995-01-01   61296.52637  1995
# 13  Hammersmith & Fulham  E09000013 1995-01-01  124902.86020  1995
# 14              Haringey  E09000014 1995-01-01   76287.56947  1995
# ...

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
print(properties_filtered.dtypes)
# Out:
# Borough              object
# Geocode              object
# Date         datetime64[ns]
# Avg_Price           float64
# Year                  int64
# dtype: object

# %%
# Convert Date column to datetime
properties_melted['Date'] = pd.to_datetime(properties_melted['Date'])
# Convert Values to float
properties_melted['Avg_Price'] = properties_melted['Avg_Price'].astype(float)
print(properties_melted.dtypes)
# Out:
# Borough              object
# Geocode              object
# Date         datetime64[ns]
# Avg_Price           float64
# Year                  int64
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
# Count null values in Borough column
null_counts = properties_melted['Borough'].isnull().sum()
print(null_counts)
# Out:
# 0

# %%
# Check how many entries are in column Borough
num_entries_len = len(properties_melted['Borough'])
print(num_entries_len)
# Find the number of non-null entries in the 'Borough' column using count()
num_entries_count = properties_melted['Borough'].count()
print(num_entries_count)
# Out:
# 16848
# 16848

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
borough_df = properties_filtered[properties_filtered['Borough'] == 'Brent']

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(borough_df['Date'], borough_df['Avg_Price'], marker='', linestyle='-')
plt.title('Average Price Over Time for Brent')
plt.xlabel('Date')
plt.ylabel('Average Price')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
# Group by the Year column and aggregate the Avg_Price column
properties_grouped = properties_filtered.groupby(['Year', 'Borough'])['Avg_Price'].mean().reset_index()
# Rearrange columns to make Borough the first column
properties_grouped = properties_grouped[['Borough', 'Year', 'Avg_Price']]
# Sort by Borough
properties_grouped = properties_grouped.sort_values(by=['Borough','Year'])
# Adjust index
properties_grouped.index = properties_grouped.index+1
properties_grouped.head(20)
# Out:
#                 Borough  Year      Avg_Price
# 1    Barking & Dagenham  1995   51817.969390
# 33   Barking & Dagenham  1996   51718.192690
# 65   Barking & Dagenham  1997   55974.262309
# 97   Barking & Dagenham  1998   60285.821083
# 129  Barking & Dagenham  1999   65320.934441
# 161  Barking & Dagenham  2000   77549.513290
# 193  Barking & Dagenham  2001   88664.058223
# 225  Barking & Dagenham  2002  112221.912482
# 257  Barking & Dagenham  2003  142498.927800
# 289  Barking & Dagenham  2004  158175.982483
# 321  Barking & Dagenham  2005  163360.782017
# 353  Barking & Dagenham  2006  167853.342558
# 385  Barking & Dagenham  2007  184909.807383
# 417  Barking & Dagenham  2008  187356.865783
# 449  Barking & Dagenham  2009  156446.896358
# 481  Barking & Dagenham  2010  166560.705275
# 513  Barking & Dagenham  2011  163465.144225
# 545  Barking & Dagenham  2012  165863.911600
# 577  Barking & Dagenham  2013  173733.624933
# 609  Barking & Dagenham  2014  201172.229417

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
def create_price_ratio(df, borough):
    """
    Calculate the ratio of house prices in 1998 to 2018 for a given borough.
    
    Parameters:
    df (DataFrame): The DataFrame containing the house prices data.
    borough (str): The name of the borough to filter the data.
    
    Returns:
    float: The ratio of the average price in 1998 to the average price in 2018.
    """
    # Filter the DataFrame for the specified borough
    borough_data = df[df['Borough'] == borough]
    
    # Filter the data for the years 1998 and 2018
    data_1998 = borough_data[borough_data['Year'] == 1998]
    data_2018 = borough_data[borough_data['Year'] == 2018]
    
    # Calculate the average price for 1998 and 2018
    avg_price_1998 = data_1998['Avg_Price'].mean()
    avg_price_2018 = data_2018['Avg_Price'].mean()
    
    # Calculate the price ratio
    price_ratio = avg_price_1998 / avg_price_2018
    
    return price_ratio

# %%
create_price_ratio(properties_grouped, 'Brent')
# Out:
# 0.2043086864360114

# %%
# Run create_price_ratio through all boroughs and make a df of returns
boroughs = properties_filtered['Borough'].unique()
results=[]
for borough in boroughs:
    ratio = create_price_ratio(properties_filtered, borough)
    results.append({'Borough': borough, 'Price_Ratio': ratio})
result_df = pd.DataFrame(results)
#result_df.index = result_df.index+1
print(result_df)
# Out:
#                  Borough  Price_Ratio
# 0     Barking & Dagenham     0.204223
# 1                 Barnet     0.229453
# 2                 Bexley     0.235351
# 3                  Brent     0.204309
# 4                Bromley     0.244213
# 5                 Camden     0.202620
# 6                Croydon     0.238033
# 7                 Ealing     0.231940
# 8                Enfield     0.234551
# 9              Greenwich     0.209950
# 10               Hackney     0.161335
# 11  Hammersmith & Fulham     0.241674
# 12              Haringey     0.194756
# 13                Harrow     0.246354
# 14              Havering     0.231202
# 15            Hillingdon     0.238080
# 16              Hounslow     0.251483
# 17             Islington     0.206439
# 18  Kensington & Chelsea     0.196755
# 19  Kingston upon Thames     0.234162
# 20               Lambeth     0.201704
# 21              Lewisham     0.183512
# 22                Merton     0.210914
# 23                Newham     0.188488
# ...

# %%
result_df_sorted = result_df.sort_values(by='Price_Ratio', ascending=False)
result_df_sorted_reset = result_df_sorted.reset_index(drop=True)
result_df_sorted_reset.index = result_df_sorted_reset.index +1
print(result_df_sorted_reset)
# Out:
#                  Borough  Price_Ratio
# 1               Hounslow     0.251483
# 2   Richmond upon Thames     0.249678
# 3                 Harrow     0.246354
# 4                Bromley     0.244213
# 5                 Sutton     0.242806
# 6   Hammersmith & Fulham     0.241674
# 7             Hillingdon     0.238080
# 8                Croydon     0.238033
# 9                 Bexley     0.235351
# 10               Enfield     0.234551
# 11  Kingston upon Thames     0.234162
# 12                Ealing     0.231940
# 13              Havering     0.231202
# 14                Barnet     0.229453
# 15             Redbridge     0.223655
# 16         Tower Hamlets     0.216137
# 17                Merton     0.210914
# 18            Wandsworth     0.210185
# 19             Greenwich     0.209950
# 20             Islington     0.206439
# 21                 Brent     0.204309
# 22    Barking & Dagenham     0.204223
# 23                Camden     0.202620
# 24               Lambeth     0.201704
# ...

# %%
# Highlighting the top 3 boroughs
top_3_index = result_df_sorted.head(3).index

# Set color with top 3 highlighted in red
colors = ['red' if i in top_3_index else 'skyblue' for i in result_df_sorted.index]

# Plotting the graph
plt.figure(figsize=(12, 8))
plt.bar(result_df_sorted['Borough'], result_df_sorted['Price_Ratio'], color=colors)
plt.title('Price Ratio by London Borough')
plt.xlabel('Borough')
plt.ylabel('Price Ratio')
plt.xticks(rotation=90)
plt.tight_layout()

# Show the plot
plt.show()

# %%
borough_df_filt = properties_grouped.loc[properties_grouped['Borough'].isin(boroughs)]

# %%
borough_df_filt.head(100)
# Out:
#                 Borough  Year      Avg_Price
# 1    Barking & Dagenham  1995   51817.969390
# 33   Barking & Dagenham  1996   51718.192690
# 65   Barking & Dagenham  1997   55974.262309
# 97   Barking & Dagenham  1998   60285.821083
# 129  Barking & Dagenham  1999   65320.934441
# ..                  ...   ...            ...
# 164               Brent  2000  140962.500458
# 196               Brent  2001  157287.404625
# 228               Brent  2002  185898.147992
# 260               Brent  2003  216501.757008
# 292               Brent  2004  236023.435958
#
# [100 rows x 3 columns]

# %%
print(boroughs_most_expensive_2024.dtypes)
# Out:
# Borough       object
# Year           int64
# Avg_Price    float64
# dtype: object

# %%
# List of most expensive boroughs 2024
boroughs_most_expensive_2024 = borough_df_filt[borough_df_filt['Year'] == 2024].sort_values(by='Avg_Price', ascending=False)
boroughs_most_expensive_2024 = boroughs_most_expensive_2024.reset_index(drop=True)
boroughs_most_expensive_2024.index = boroughs_most_expensive_2024.index + 1

# Change format in Avg_Price so the full number is displayed
pd.set_option('display.float_format', '{:.0f}'.format)

print(boroughs_most_expensive_2024)
# Out:
#                  Borough  Year  Avg_Price
# 1   Kensington & Chelsea  2024    1201067
# 2            Westminster  2024     948437
# 3                 Camden  2024     759645
# 4   Richmond upon Thames  2024     736269
# 5   Hammersmith & Fulham  2024     733986
# 6              Islington  2024     663342
# 7             Wandsworth  2024     611502
# 8                Hackney  2024     587148
# 9                 Barnet  2024     581193
# 10              Haringey  2024     562951
# 11                Merton  2024     555232
# 12  Kingston upon Thames  2024     534534
# 13                Ealing  2024     525009
# 14                 Brent  2024     523451
# 15                Harrow  2024     516115
# 16               Lambeth  2024     505314
# 17               Bromley  2024     498638
# 18        Waltham Forest  2024     493868
# 19             Southwark  2024     493828
# 20             Redbridge  2024     467218
# 21             Greenwich  2024     454505
# ...

# %%
# Plotting all boroughs on the same graph with appropriate labels
plt.figure(figsize=(14, 8))
for borough in borough_df_filt['Borough'].unique():
    borough_data = borough_df_filt[borough_df_filt['Borough'] == borough]
    plt.plot(borough_data['Year'], borough_data['Avg_Price'], label=borough)

plt.xlabel('Date')
plt.ylabel('Average Price')
plt.title('Average House Prices by Borough')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
# Calculate the average price over all years for each borough
average_prices = borough_df_filt.groupby('Borough')['Avg_Price'].mean().sort_values(ascending=False)

# Get the top 3 boroughs with the highest average prices
top_3_boroughs = average_prices.head(3).index

# Plotting all boroughs on the same graph with top 3 highlighted in the legend
plt.figure(figsize=(14, 8))
for borough in borough_df_filt['Borough'].unique():
    borough_data = borough_df_filt[borough_df_filt['Borough'] == borough]
    if borough in top_3_boroughs:
        plt.plot(borough_data['Year'], borough_data['Avg_Price'], label=borough, linewidth=3)
    else:
        plt.plot(borough_data['Year'], borough_data['Avg_Price'], label=borough, alpha=0.5)

plt.xlabel('Year')
plt.ylabel('Average Price (£ mln)')
plt.title('Average House Prices by Borough')
plt.yticks(range(0, 1600001, 100000))  # Set y-axis with full numbers and a step of 100,000
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# Based on the data analysis we can say that Top-3 boroughs with the highst price increase between 1998 and 2018 are:
# 1               Hounslow     0.251483
# 2   Richmond upon Thames     0.249678
# 3                 Harrow     0.246354
#
# While most expensive overall in 2024 are:
#
# 1   Kensington & Chelsea     1201067
# 2            Westminster     948437
# 3                 Camden     759645
#
# We can see that during the last two years, the London real estate market has been mostly flat, with a significant exception in the top three most expensive boroughs, where we have observed one of the biggest price decreases since 1998. A deeper analysis of each borough should be performed to determine the root cause of this behavior and to investigate if it is influenced by any outliers, crime rates, immigration, etc.
